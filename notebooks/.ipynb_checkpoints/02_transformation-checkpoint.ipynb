# %% [markdown]
# ### Notebook 3 — Jointures et agrégations

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import to_date, year, col, round, concat_ws
from pyspark.sql.types import DoubleType, IntegerType
from pyspark.sql.functions import trim, initcap, upper, col
from collections import Counter

# %% [markdown]
# ##### SparkSession

# %%
spark = SparkSession.builder.appName("TradeCorp ETL").getOrCreate()

# %% [markdown]
# ##### chargement de parquet files pour la transformation

# %%
#Lecture simple d’un Parquet

DATA_PATH = "/home/jovyan/data/tmp/clean"   # adapte selon ton volume Docker

# Lecture des fichiers Parquet
df_categories = spark.read.parquet(f"{DATA_PATH}/categories/")
df_customers = spark.read.parquet(f"{DATA_PATH}/customers_clean/")
df_employees = spark.read.parquet(f"{DATA_PATH}/employees_clean/")
df_supply = spark.read.parquet(f"{DATA_PATH}/en_stock/")
df_shippers = spark.read.parquet(f"{DATA_PATH}/is_shipped/")
df_order_details = spark.read.parquet(f"{DATA_PATH}/order_details_final/")
df_orders = spark.read.parquet(f"{DATA_PATH}/orders_1997/")
df_products = spark.read.parquet(f"{DATA_PATH}/products_filtered/")

# Dictionnaire des DataFrames
dfs = {
    "customers_clean": df_customers,
    "employees_clean": df_employees,
    "en_stock": df_supply,
    "is_shipped": df_shippers,
    "order_details_final": df_order_details,
    "orders_1997": df_orders,
    "categories": df_categories,
    "products_filtered": df_products,    
}

# Vérification
#df_orders.show(5)
#df_orders.printSchema()

# %% [markdown]
# ##### Écriture en Parquet (Silver layer)

# %% [markdown]
# ##### A21 — Jointure orders + customers

# %%
# #Création de orders_customers silver parquet file
# volumes pour silver 
DATA_PATH_silver = "/home/jovyan/data/tmp/silver" 

df_orders_customers = (
    df_orders.alias("o")
    .join(df_customers.alias("c"), on="customer_id", how="inner")
    .select(
        "o.order_id",
        "c.company_name",
        "c.country",
        "o.order_date",
        "o.freight"
    )
)

#Vérification
df_orders_customers.show(10)
df_orders_customers.printSchema()

# # Écriture en Silver

df_orders_customers.write.mode("overwrite").parquet(f"{DATA_PATH_silver}/orders_customers")
# Out:
# +--------+--------------------+---------+----------+-------+
# |order_id|        company_name|  country|order_date|freight|
# +--------+--------------------+---------+----------+-------+
# |   10400|  Eastern Connection|       UK|1997-01-01|  83.93|
# |   10401|Rattlesnake Canyo...|      USA|1997-01-01|  12.51|
# |   10402|        Ernst Handel|  Austria|1997-01-02|  67.88|
# |   10403|        Ernst Handel|  Austria|1997-01-03|  73.79|
# |   10404|Magazzini Aliment...|    Italy|1997-01-03| 155.97|
# |   10405|    LINO-Delicateses|Venezuela|1997-01-06|  34.82|
# |   10406|       Queen Cozinha|   Brazil|1997-01-07| 108.04|
# |   10407|  Ottilies Käseladen|  Germany|1997-01-07|  91.48|
# |   10408|   Folies gourmandes|   France|1997-01-08|  11.26|
# |   10409|Océano Atlántico ...|Argentina|1997-01-09|  29.83|
# +--------+--------------------+---------+----------+-------+
# only showing top 10 rows
#
# root
#  |-- order_id: integer (nullable = true)
#  |-- company_name: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- freight: double (nullable = true)

# %%
print(df_order_details_products.columns)
print(df_products.columns)
# Out:
# ['odp_order_id', 'product_id', 'odp_prix_unitaire', 'odp_quantite', 'odp_discount', 'odp_product_name', 'odp_category_id', 'odp_unit_price']
# ['product_id', 'product_name', 'supplier_id', 'category_id', 'quantity_per_unit', 'unit_price', 'units_in_stock', 'units_on_order', 'reorder_level', 'discontinued']

# %% [markdown]
# ##### A22 — Jointure order_details + products

# %%
# volumes pour silver 
DATA_PATH_silver = "/home/jovyan/data/tmp/silver" 

df_order_details_products = (
    df_order_details.alias("od")
    .join(df_products.alias("p"), on="product_id", how="inner")
    .select(
        "od.order_id",
        "od.product_id",
        "od.prix_unitaire",
        "od.quantite",
        "od.discount",
        "p.product_name",
        "p.category_id",
        "p.unit_price"
    )
)


#Vérification
#df_order_details_products.show(10)
df_order_details_products.printSchema()

# Écriture en Silver
df_order_details_products.write.mode("overwrite").parquet(f"{DATA_PATH_silver}/order_details_products")
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- prix_unitaire: double (nullable = true)
#  |-- quantite: integer (nullable = true)
#  |-- discount: double (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)

# %% [markdown]
# ##### Jointure products + categories

# %%
# products_categories parquet file

DATA_PATH_silver = "/home/jovyan/data/tmp/silver" 

df_products_categories = (
    df_products.alias("p")
    .join(df_categories.alias("c"), on="category_id", how="left")
    .select(
        "p.product_id",
        "p.product_name",
        "p.supplier_id",
        "p.category_id",
        "c.category_name",
        "c.description",
        "p.quantity_per_unit",
        "p.unit_price",
        "p.units_in_stock",
        "p.units_on_order",
        "p.reorder_level",
        "p.discontinued"
    )
)
#Vérification

#df_products_categories.show(10)
df_products_categories.printSchema()

#Écriture en Silver
df_products_categories.write.mode("overwrite").parquet(f"{DATA_PATH_silver}/products_categories")
# Out:
# root
#  |-- product_id: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- supplier_id: integer (nullable = true)
#  |-- category_id: integer (nullable = true)
#  |-- category_name: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- quantity_per_unit: string (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- units_in_stock: integer (nullable = true)
#  |-- units_on_order: integer (nullable = true)
#  |-- reorder_level: integer (nullable = true)
#  |-- discontinued: integer (nullable = true)

# %% [markdown]
# ##### DataFrame enrichi complet

# %%
# products enriched

DATA_PATH_silver = "/home/jovyan/data/tmp/silver"
#Enrichir les produits avec les catégories
df_products_enriched = (df_products.alias("p").join(df_categories.alias("c"), on="category_id", how="left"))
#Ecrire en silver
df_products_enriched.write.mode("overwrite").parquet(f"{DATA_PATH_silver}/products_enriched")

# %% [markdown]
# ##### Rénomer les colonnes

# %%
print(df_orders_customers.columns)
print(df_order_details_products.columns)
print(df_products_categories.columns)
print(df_products_enriched.columns)
# Out:
# ['order_id', 'orders_customers_company_name', 'country', 'order_date', 'freight']
# ['order_id', 'product_id', 'prix_unitaire', 'quantite', 'discount', 'product_name', 'category_id', 'unit_price']
# ['product_id', 'product_name', 'supplier_id', 'category_id', 'category_name', 'description', 'quantity_per_unit', 'unit_price', 'units_in_stock', 'units_on_order', 'reorder_level', 'discontinued']
# ['category_id', 'product_id', 'product_name', 'supplier_id', 'quantity_per_unit', 'unit_price', 'units_in_stock', 'units_on_order', 'reorder_level', 'discontinued', 'category_name', 'description', 'picture']

# %%
# Création de volume bronze

# Définition du chemin Bronze
DATA_PATH_BRONZE = "/home/jovyan/data/tmp/bronze"

# Renaming of columns to avoid duplication

#prders_customers 

#'order_id', 'company_name', 'country', 'order_date', 'freight'
df_orders_customers = (
    df_orders_customers
    .withColumnRenamed("order_id", "order_id")
    .withColumnRenamed("company_name", "oc_company_name")
    .withColumnRenamed("region", "oc_region")
    .withColumnRenamed("postal_code", "oc_postal_code")
    .withColumnRenamed("customer_id", "oc_customer_id")
)

# df_order_details_products
df_order_details_products = (
    df_order_details_products
    .withColumnRenamed("order_id", "odp_order_id")
    .withColumnRenamed("product_id", "product_id")
    .withColumnRenamed("prix_unitaire", "odp_prix_unitaire")
    .withColumnRenamed("quantite", "odp_quantite")
    .withColumnRenamed("discount", "odp_discount")
    .withColumnRenamed("product_name", "odp_product_name")
    .withColumnRenamed("category_id", "odp_category_id")
    .withColumnRenamed("unit_price", "unit_price")
)

#'order_id', 'product_id', 'prix_unitaire', 'quantite', 'discount', 'product_name', 'category_id', 'unit_price'

# df_products_categories
    
df_products_categories = (
    df_products_categories
    .withColumnRenamed("product_id", "pc_product_id")
    .withColumnRenamed("product_name", "pc_product_name")
    .withColumnRenamed("supplier_id", "pc_supplier_id")
    .withColumnRenamed("category_id", "pc_category_id")
    .withColumnRenamed("category_name", "pc_category_name")
    .withColumnRenamed("description", "pc_description")
    .withColumnRenamed("quantity_per_unit", "pc_quantity_per_unit")
    .withColumnRenamed("units_on_order", "pc_units_on_order")
    .withColumnRenamed("reorder_level", "pc_reorder_level")
    .withColumnRenamed("discontinued", "pc_discontinued")
)

#['product_id', 'product_name', 'supplier_id', 'category_id', 'category_name', 'description', 'quantity_per_unit',
#'unit_price', 'units_in_stock', 'units_on_order', 'reorder_level', 'discontinued']

# shippers
df_products_enriched = (
    df_products_enriched
    .withColumnRenamed("product_id", "pe_product_id")
    .withColumnRenamed("category_id", "pe_category_id")
    .withColumnRenamed("product_name", "pe_product_name")
    .withColumnRenamed("supplier_id", "pe_supplier_id")
    .withColumnRenamed("quantity_per_unit", "pe_quantity_per_unit")
    .withColumnRenamed("unit_price", "pe_unit_price")
    .withColumnRenamed("units_in_stock", "pe_units_in_stock")
    .withColumnRenamed("units_on_order", "pe_units_on_order")
    .withColumnRenamed("reorder_level", "pe_reorder_level")
    .withColumnRenamed("discontinued", "pe_discontinued")
    .withColumnRenamed("product_category_name", "pe_product_category_name")
    .withColumnRenamed("product_category_description", "pe_product_category_description")
    .withColumnRenamed("picture", "pe_picture")
)

#['category_id', 'product_id', 'product_name', 'supplier_id', 'quantity_per_unit', 'unit_price', 'units_in_stock', 'units_on_order',
 #'reorder_level', 'discontinued', 'category_name', 'description', 'picture']


# Jointure complète (order_details → orders → customers → products → employees → shippers)
# Jointure complète

from pyspark.sql.functions import col


df_full = (
    df_orders_customers.alias("oc")
    .join(
        df_order_details_products.alias("odp"),
        col("oc.order_id") == col("odp.odp_order_id"),
        "inner"
    )
    .join(
        df_products_categories.alias("pc"),
        col("odp.product_id") == col("pc.pc_product_id"),
        "left"
    )
    .join(
        df_products_enriched.alias("pe"),
        col("pc.pc_product_id") == col("pe.pe_product_id"),
        "left"
    )
)


#col("oc.order_id") == col("odp.order_id")
#col("oc.order_id_orders_customers") == col("odp.order_id_order_details_products")


# Colonnes dupliquées
cols = df_full.columns
duplicates = [col for col, count in Counter(cols).items() if count > 1]

print("Colonnes dupliquées :", duplicates)

# Vérification
df_full.printSchema()

# Écriture en Bronze
df_full.write.mode("overwrite").parquet(f"{DATA_PATH_BRONZE}/full_join")
# Out:
# Colonnes dupliquées : ['unit_price']
# root
#  |-- order_id: integer (nullable = true)
#  |-- orders_customers_company_name: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- freight: double (nullable = true)
#  |-- odp_order_id: integer (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- odp_prix_unitaire: double (nullable = true)
#  |-- odp_quantite: integer (nullable = true)
#  |-- odp_discount: double (nullable = true)
#  |-- odp_product_name: string (nullable = true)
#  |-- odp_category_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- pc_product_id: integer (nullable = true)
#  |-- pc_product_name: string (nullable = true)
#  |-- pc_supplier_id: integer (nullable = true)
#  |-- pc_category_id: integer (nullable = true)
#  |-- pc_category_name: string (nullable = true)
#  |-- pc_description: string (nullable = true)
#  |-- pc_quantity_per_unit: string (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- units_in_stock: integer (nullable = true)
#  |-- pc_units_on_order: integer (nullable = true)
#  |-- pc_reorder_level: integer (nullable = true)
#  |-- pc_discontinued: integer (nullable = true)
#  |-- pe_category_id: integer (nullable = true)
#  |-- pe_product_id: integer (nullable = true)
#  |-- pe_product_name: string (nullable = true)
#  |-- pe_supplier_id: integer (nullable = true)
#  |-- pe_quantity_per_unit: string (nullable = true)
#  |-- pe_unit_price: double (nullable = true)
#  |-- pe_units_in_stock: integer (nullable = true)
#  |-- pe_units_on_order: integer (nullable = true)
#  |-- pe_reorder_level: integer (nullable = true)
#  |-- pe_discontinued: integer (nullable = true)
#  |-- category_name: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- pe_picture: string (nullable = true)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[28], line 116
#     113 df_full.printSchema()
#     115 # Écriture en Bronze
# --> 116 df_full.write.mode("overwrite").parquet(f"{DATA_PATH_BRONZE}/full_join")
#
# File /usr/local/spark/python/pyspark/sql/readwriter.py:1656, in DataFrameWriter.parquet(self, path, mode, partitionBy, compression)
#    1654     self.partitionBy(partitionBy)
#    1655 self._set_opts(compression=compression)
# -> 1656 self._jwrite.parquet(path)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /usr/local/spark/python/pyspark/errors/exceptions/captured.py:175, in capture_sql_exception.<locals>.deco(*a, **kw)
#     171 converted = convert_exception(e.java_exception)
#     172 if not isinstance(converted, UnknownException):
#     173     # Hide where the exception came from that shows a non-Pythonic
#     174     # JVM exception message.
# --> 175     raise converted from None
#     176 else:
#     177     raise
#
# AnalysisException: [COLUMN_ALREADY_EXISTS] The column `unit_price` already exists. Consider to choose another name or rename the existing column.

# %%
print(df_orders_customers_final.columns)
print(df_order_details_products_final.columns)
